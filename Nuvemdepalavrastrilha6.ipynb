# %% [markdown]
# <a href="https://colab.research.google.com/github/Carol-Piva/Carol-Piva.github.io/blob/main/Nuvemdepalavrastrilha6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.3 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4

# %%
import requests
import csv
import pandas as pd

# %%
import pandas as pd
df = pd.read_json('https://raw.githubusercontent.com/Carol-Piva/Mackenziebigdatarecuperacaodedados/main/starturls.json')

titles = df[['title']].copy()
titles.head(50)
# Out:
#                                                 title
# 0    Samsung Galaxy A32 Dual SIM 128 GB azul 4 GB RAM
# 1   Apple Macbook Air (13 polegadas, 2020, Chip M1...
# 2    Aquecedor A Gás 20 Litros Komeco Digital Glp ...
# 3   Notebook Gamer Alienware M15 I7 11800h 16gb 1t...
# 4   Capacete Moto Fechado R8 Viseira Fumê Pro Tork...
# 5      Nokia Cseries C20 Dual SIM 32 GB azul 2 GB RAM
# 6                      TV Multilaser TL016 LED HD 24"
# 7   Notebook Lenovo IdeaPad 3i prata 15.6", Intel ...
# 8                Aquecedor elétrico Mondial A-08 220V
# 9   Cadeira de escritório Mymax MX7 gamer ergonômi...
# 10  Kit Notebook Dell Fhd 11ª Intel I7 16gb 512gb ...
# 11  Apple iPad Air de 10.9" WI-FI  64GB Cinza-espa...
# 12  Camera Gopro Hero 10 Black Pronta Entrega Nfe ...
# 13  Módulo Amplificador Taramps Ts-400x4 Digital 4...
# 14  Geladeira frost free Brastemp BRM44H inox com ...
# 15  Multilaser G Max 2 (13 Mpx) Dual SIM 128 GB pr...
# 16  Fogão Profissional Alta Pressão Gás 6 Bocas Qs...
# 17  Microfones JWL U-585 dinâmico  unidirecional p...
# 18  Notebook Positivo BGH Motion Q4128C gray 14.1"...
# 19  Fogão  de piso Itatiaia  Star 4Q  gás engarraf...
# 20  Jogo 4 Bico Injetor Renault Master 2.3 16v M9t...
# 21  Moedor De Café Hamilton Beach Elétrico Em Inox...
# 22  Fogão cooktop gás Braslar Pop 5 Bocas preto 12...
# 23  Trio Capa Cilindro + Painel Temático Veste Fác...
# 24  Lava e seca automática Midea LSE12 inverter gr...
# 25  Notebook Acer Nitro 5 8gb 1tb 256gb Ssd Tela 1...
# 26                 LG K62 Dual SIM 64 GB red 4 GB RAM
# 27  Máquina de lavar automática Consul CWH11B bran...
# 28  Computador Fácil Intel Core I3 10100f 4gb Ddr4...
# 29               Smart TV LG 24TL520S-PS LED HD 23.6"
# 30             Pneu Pirelli P400 EVO P 175/65R14 82 H
# 31  Fueltech Wideband Nano Com Sonda Bosch 2 Metro...
# 32  Motorola Edge 20 Pro Dual SIM 256 GB azul 12 G...
# 33  Xiaomi Pocophone Poco X3 Dual SIM 64 GB out of...
# 34  Philco Hit P10 Dual SIM 128 GB space gray 4 GB...
# 35  Tripé Câmera Profissional Canon 1,80 Mts + Sup...
# 36  Smartphone Tcl T810h 20 Pro 5g 256gb Cinza 6gb...
# 37    Microsoft Xbox Series X 1TB Standard cor  preto
# 38  Aspirador de pó Wap GTW 10 10L amarelo e preto...
# 39    Pneu Apollo Aro 14 Amazer 3g Maxx 175/65r14 82t
# 40  Notebook Acer Aspire 5 A515-54 prata 15.6", In...
# 41  Kit 10 Farol Milha 16 Led 48w 12v/24v Quadrad ...
# 42  Extratora industrial Wap Carpet Cleaner Pro 30...
# 43  4 Strobo Automotivo Carro Ajk 4 Faróis Rgb Com...
# 44  Nintendo Switch 32GB Standard cor  vermelho-né...
# 45  Smart Tv 70 Polegadas Uhd 4k Wifi Crystal Hdr ...
# 46  Secadora de roupas Mueller Sun elétrica 8kg br...
# 47     Pneu Firestone F-Series F-600 P 175/70R14 84 T
# 48   Samsung Galaxy A32 Dual SIM 128 GB azul 4 GB RAM
# 49  Apple Macbook Air (13 polegadas, 2020, Chip M1...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

original_text = ' '.join(titles['title'])

wordcloud2 = WordCloud(collocations=False, normalize_plurals=False, stopwords=None, width=980, height=300, background_color='black', max_words=350).generate(original_text)
                     
plt.figure(figsize = (18, 18), facecolor = 'White') 
plt.imshow(wordcloud2)
plt.axis("off")
def singularizar(PalavraOriginal):
   palavra = PalavraOriginal.lower()
import nltk
from nltk.corpus import stopwords
from unidecode import unidecode
import string
nltk.download('stopwords')  
stop = stopwords.words('portuguese')
titles['title_treated'] = titles['title_treated'].str.lower().apply(lambda x: ' '.join([word for word in x.split() if word not in (ignorewords)]))

plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
titles['title_treated'] = titles['title'].apply(lambda x: unidecode(x))

# %%
"""
Thanks for https://simasware.wordpress.com/2014/02/28/pluralizacao-em-pt-br-rails/
"""

import re
import unicodedata
import string

INVARIAVEL = [  'de',
                'gb',
                'bocas',
                'sim',
                '127',
                'bônus'            ]

def singularizar(PalavraOriginal):
    """ Remove acentos e deixa tudo minuscula"""
    palavra = PalavraOriginal.lower()

    # for wd in INVARIAVEL:
    #     if transliterate(wd).lower() == palavra:
    #         return palavra

    """      Lista de regras, composto em tuplas de valor a ser buscado e regra de substituição    """
    rules = []

    """    Palavras terminadas em ns    """
    rules.append((r"^([a-zA-z]*)ns$", r"\1m"))

    """ Palavras terminas em r ou z luzes - luz, flores - flor, arrozes - arroz"""
    rules.append((r"^([a-zA-z]*)res$", r"\1r"))
    rules.append((r"^([a-zA-z]*)zes$", r"\1z"))
    rules.append((r"^([a-zA-z]*)ses$", r"\1s"))

    """    Palavras terminadas em ão    """
    rules.append((r"^([a-zA-z]*)oes$", r"\1ao"))
    rules.append((r"^([a-zA-z]*)aos$", r"\1ao"))
    rules.append((r"^([a-zA-z]*)aes$", r"\1ao"))

    """ Palavras regulares, casos simples: carros, arvores, aboboras"""
    rules.append((r"^([a-zA-z]*)(a|e|o|u)is$", r"\1\2l"))

    """ Palavras terminas em il  cantis - cantil """
    rules.append((r"^([a-zA-z]*)is$", r"\1il"))

    """ Palavras terminas em les  mal - males, mel - meles """
    rules.append((r"^([a-zA-z]*)les$", r"\1l"))


    """ Palavras regulares, casos simples: carros, arvores, aboboras"""
    rules.append((r"^([a-zA-z]*)(a|e|i|o|u)s$", r"\1\2"))
    
    for rule in rules:
        if re.match(rule[0], palavra) is not None:
            return re.sub(rule[0], rule[1], palavra, 1, re.IGNORECASE)
    return palavra

# %%
titles['title_treated']
# Out:
# 0       Samsung Galaxy A32 Dual SIM 128 GB azul 4 GB RAM
# 1      Apple Macbook Air (13 polegadas, 2020, Chip M1...
# 2       Aquecedor A Gas 20 Litros Komeco Digital Glp ...
# 3      Notebook Gamer Alienware M15 I7 11800h 16gb 1t...
# 4      Capacete Moto Fechado R8 Viseira Fume Pro Tork...
#                              ...
# 523    4 Strobo Automotivo Carro Ajk 4 Farois Rgb Com...
# 524    Nintendo Switch 32GB Standard cor  vermelho-ne...
# 525    Smart Tv 70 Polegadas Uhd 4k Wifi Crystal Hdr ...
# 526    Secadora de roupas Mueller Sun eletrica 8kg br...
# 527       Pneu Firestone F-Series F-600 P 175/70R14 84 T
# Name: title_treated, Length: 528, dtype: object

# %%
#cria uma lista com todos os tokens
from nltk.tokenize import word_tokenize
nltk.download('punkt')

big_line = ' '.join(sent for sent in titles['title_treated'])
tokens = word_tokenize(big_line)
fdist1 = nltk.FreqDist(tokens)
fdist1 = sorted(fdist1.items(), key=lambda x: x[1], reverse=True)
pd_freq = pd.DataFrame.from_dict(fdist1)
n = 0
pd_freq.iloc[n:n+60]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#            0    1
# 0         GB  176
# 1          ,  132
# 2         de  132
# 3        RAM  121
# 4          4   88
# 5      Intel   88
# 6      preto   88
# 7       Dual   77
# 8        SIM   77
# 9   Notebook   66
# 10        ''   66
# 11         e   55
# 12        10   55
# 13      azul   44
# 14       SSD   44
# 15       Pro   44
# 16       128   33
# 17         (   33
# 18         )   33
# 19       Gas   33

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
# from nltk.tokenize import word_tokenize

treated_text = ' '.join(titles['title_treated'])

wordcloud2 = WordCloud(collocations=False, normalize_plurals=False, stopwords=None, width=980, height=300, background_color='black', max_words=60).generate(treated_text)
# Generate plot
# plot the WordCloud image                        
plt.figure(figsize = (18, 18), facecolor = None) 
plt.imshow(wordcloud2)
plt.axis("off")
ignorewords = ['gb', 'de', '127v', '220v','sim','d e', 'g b']
plt.show()
